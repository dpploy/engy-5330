# %% [markdown]
# Engy-5310: Computational Continuum Transport Phenomena Spring 2021 UMass Lowell; Prof. V. F. de Almeida **19Feb21**
#
# # Howmework 07 (19Feb21)
#
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\fvec}{\boldsymbol{\mathsf{f}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\rank}{rank}
#   \newcommand{\Reals}{\mathbb{R}}
#   \newcommand{\thetavec}{\boldsymbol{\theta}}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |       Context               |  Points |
# | -----------------------     | ------- |
# | Precision of the answer     |   80%   |
# | Answer Markdown readability |   10%   |
# | Code readability            |   10%   |

# %% [markdown]
# ### <span style="color:red">Guidance:</span>
#
# +  <span style="color:red">
#     Save your work frequently to a file locally to your computer.
#    </span>
# +  <span style="color:red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<span style="color:red">, to verify your notebook runs correctly.
#    </span>
# +  <span style="color:red">
#     Save your file again.
#    </span>
# +  <span style="color:red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </span>
#
#    **lastname-firstname-labwork-xx.ipynb**

# %% [markdown]
# ---
# ## Table of Assignments<a id="toa"></a>
# * [Assignment 1 (95 pts)](#a1) Function approximation with basis functions.
#  - [1.1)](#a11)(20 pts) Generate a function solving a 1D Poisson problem.
#  - [1.2)](#a12)(15 pts) Approximate function with 2 Fourier modes.
#  - [1.3)](#a13)(10 pts) Analyse boundary values.
#  - [1.4)](#a14)(15 pts) Approximate function with 3 Fourier modes.
#  - [1.5)](#a15)(10 pts) Analyse boundary values.
#  - [1.6)](#a16)(25 pts) Approximate function with quadratic Lagrange basis functions.
# * [Assignment 2 (5 pts)](#a2)
# ---

# %% [markdown]
# ## <span style="color:blue">[Assignment 1 (95 pts)](#toa)</span><a id="a1"></a>

# %% [markdown]
# ### <span style="color:blue">[1.1)](#toa)(20 pts) Solve the Poisson model problem below.</span>
# <br>
# <span style="color:blue">
#
# Find $f:[a,b]\in\Reals\rightarrow\Reals$ for $C \ne 0$ such that:
#
# \begin{align*}
#  f''(x) &= C \quad \forall \quad x\in [a,b], \\
#  f(a) &= A, \\
#  f(b) &= B.
# \end{align*}
#
# for the values
#   + $\hat{x}^* = -0.12$,
#   + $\hat{f}^* := f(\hat{x}^*) = 1$ .
#
# Define $L:= b-a$, $\hat{x} := \frac{x-a}{L} - \frac{1}{2}$, and $\hat{f}(\hat{x}) := \frac{f(x)}{C\,L^2} + \frac{1}{8}$. Denote the point $\bigl(\hat{x}^*, \hat{f}^*\bigr)$ as the <b>minimum</b> of the solution $\hat{f}:[-\frac{1}{2},\frac{1}{2}]\in\Reals\rightarrow\Reals$ of the problem.
#
# Make a plot of the solution.
# <span style="color:blue"> </span><a id="a11"></a>

# %%
'''1-D Poisson equation solution f'''

# %% [markdown]
# ### <span style="color:blue">[1.2)](#toa)(25 pts) Compute an approximant function $g$ using a Fourier basis function of 2 modes approximation by minimizing the residual vector on 7 equally spaced collocation points in $x$, Explain the goodness of the approximation.
# </span><a id="a12"></a>

# %%
'''Collocation abscissa points'''

# %%
'''Build the basis function evaluation matrix and target function vector at the collocation points'''
# Out:
# A is overdetermined.

# %%
'''Compute optimal coefficient vector'''
# Out:
# A is full rank.
#
# ||r^*||_2 =  8.669e-02

# %%
'''Build the best approximant function'''

# %%
'''Plot comparison of f and g_best_vec'''

# %%
'''L2 norm error'''
# Out:
# ||f||_L2 = (1.0501000777703684, 1.2242542239230644e-14)
#
# ||g||_L2 = 1.0529893737900833
# quadrature error = 1.2310004361346105e-14
#
# ||f-g||_L2 = 0.04978496973490503
# quadrature error = 1.639480338530455e-14
#
# Relative error [%] = 4.74097381657292

# %%
'''Residual of the best approximant'''
# Out:
# Positives at collocation pts =  3
# Negatives at collocation pts =  4
# Positives =  120
# Negatives =  130

# %% [markdown]
# <span style="color:blue">
# <b>Explanation:</b>
# </span>

# %% [markdown]
# ### <span style="color:blue">[1.3)](#toa)(10 pts) Compute the end values $g(-0.5)$ and $g(0.5)$. Show they are close to $\frac{\hat{A}+\hat{B}}{2}$ and that the difference is on the order of the residual at the end points. Explain.
# </span><a id="a13"></a>

# %%
# Out:
# g_hat(-0.5) = [1.12841]
# g_hat( 0.5) = [1.12841]
#
# A_hat = 1.07220e+00
# B_hat = 1.19220e+00
# (A_hat + B_hat)/2 = 1.13220e+00
#
# g_hat(-0.5) - (A_hat + B_hat)/2 = -3.78788e-03
# g_hat( 0.5) - (A_hat + B_hat)/2 = -3.78788e-03
#
# r(-0.5) = 6.37879e-02
# r( 0.5) = -5.62121e-02

# %% [markdown]
# ### <span style="color:blue">[1.4)](#toa)(15 pts) Compute an approximant function $g$ using a Fourier basis function of 3 modes approximation by minimizing the residual vector on 7 equally spaced collocation points in $x$. Compare with Assignment 1.2), plot the residual and explain the result.
# </span><a id="a14"></a>

# %%
'''Build the basis function evaluation matrix and target function vector at the collocation points'''
# Out:
# A is determined.

# %%
'''Compute optimal coefficient vector'''
# Out:
# A is rank deficient.
#
# ||r^*||_2 =  8.485e-02

# %%
'''Build the best approximant function'''

# %%
'''Plot comparison of f and g_best_vec'''

# %%
'''L2 norm error'''
# Out:
# ||f||_L2 = (1.0501000777703684, 1.2242542239230644e-14)
#
# ||g||_L2 = 1.0523250023612791
# quadrature error = 1.9897591847827314e-11
#
# ||f-g||_L2 = 0.04873367190859138
# quadrature error = 1.0638509929765394e-10
#
# Relative error [%] = 4.640859756154429

# %%
'''Residual of the best approximant'''
# Out:
# Positives at collocation pts =  6
# Negatives at collocation pts =  1
# Positives =  158
# Negatives =  92

# %% [markdown]
# <span style="color:blue">
# <b>Explanation:</b>
# </span>

# %% [markdown]
# ### <span style="color:blue">[1.5)](#toa)(10 pts) Compute the end values $g(-0.5)$ and $g(0.5)$. Show they are "very" close to $\frac{\hat{A}+\hat{B}}{2}$ and that the difference is on the order of the residual at the end points or better. Compare to [1.3)](#a13) and explain what is happening at the boundary of the domain.
# </span><a id="a15"></a>

# %%
# Out:
# g_hat(-0.5) = [1.1322]
# g_hat( 0.5) = [1.1322]
#
# A_hat = 1.07220e+00
# B_hat = 1.19220e+00
# (A_hat + B_hat)/2 = 1.13220e+00
#
# g_hat(-0.5) - (A_hat + B_hat)/2 = -4.84992e-09
# g_hat( 0.5) - (A_hat + B_hat)/2 = -4.84992e-09
#
# r(-0.5) = 6.00000e-02
# r( 0.5) = -6.00000e-02

# %% [markdown]
# <span style="color:blue">
# <b>Explanation:</b>
# </span>

# %% [markdown]
# ### <span style="color:blue">[1.4)](#toa)(25 pts) Compute an approximant function $g$ using quadratic Lagrange  functions by minimizing the residual vector on 3 equally spaced collocation points in $x$. Plot the residual and explain the result.
# </span><a id="a14"></a>

# %%
'''Collocation abscissa points'''

# %%
'''Build the basis function evaluation matrix and target function vector at the collocation points'''
# Out:
# A is determined.

# %%
'''Compute optimal coefficient vector'''
# Out:
# A is full rank.
#
# ||r^*||_2 =  0.000e+00

# %%
'''Build the best approximant function'''

# %%
'''Plot comparison of f and g_best_vec'''

# %%
'''Relative L2 norm error'''
# Out:
# ||f||_L2 = (1.0501000777703684, 1.2242542239230644e-14)
#
# ||g||_L2 = 1.0501000777703684
# quadrature error = 1.2242542239230644e-14
#
# ||f-g||_L2 = 7.883634437852333e-17
# quadrature error = 1.0635877709173902e-32
#
# Relative error [%] = 7.507507717351388e-15

# %%
'''Residual of the best approximant'''
# Out:
# Positives at collocation pts =  0
# Negatives at collocation pts =  0
# Positives =  32
# Negatives =  34

# %% [markdown]
# <span style="color:blue">
# <b>Explanation:</b>
# </span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 2 (5 pts)](#toa)</span><a id="a2"></a>

# %% [markdown]
# ### <span style="color:blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</span>

# %% [markdown]
# **Answer:**
