# %% [markdown]
# Engy-5310: Computational Continuum Transport Phenomena Spring 2021 UMass Lowell; Prof. V. F. de Almeida **18May21**
#
# # Howmework 10 (18May21)
#
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\fvec}{\boldsymbol{\mathsf{f}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\flux}{\boldsymbol{q}}
#   \newcommand{\velocity}{\boldsymbol{v}}
#   \newcommand{\normal}{\boldsymbol{n}}
#   \newcommand{\xpoint}{\boldsymbol{x}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\rank}{rank}
#   \DeclareMathOperator{\div}{div}
#   \DeclareMathOperator{\grad}{grad}
#   \newcommand{\Reals}{\mathbb{R}}
#   \newcommand{\thetavec}{\boldsymbol{\theta}}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |       Context               |  Points |
# | -----------------------     | ------- |
# | Precision of the answer     |   80%   |
# | Answer Markdown readability |   10%   |
# | Code readability            |   10%   |

# %% [markdown]
# ### <span style="color:red">Guidance:</span>
#
# +  <span style="color:red">
#     Save your work frequently to a file locally to your computer.
#    </span>
# +  <span style="color:red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<span style="color:red">, to verify your notebook runs correctly.
#    </span>
# +  <span style="color:red">
#     Save your file again.
#    </span>
# +  <span style="color:red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </span>
#
#    **lastname-firstname-labwork-xx.ipynb**

# %% [markdown]
# ---
# ## Table of Assignments<a id="toa"></a>
# * [Assignment 1 (40 pts)](#a1) Poisson axisymmetric heat conduction on an annulus.
#  - [1.1)](#a11)(10 pts) State the Galerkin weak formulation.
#  - [1.2)](#a12)(10 pts) When is the weak formulation equivalent to a variational formulation?
#  - [1.3)](#a13)(10 pts) Solve the problem with the Galerkin FEM and MOOSE framework.
#  - [1.4)](#a14)(10 pts) Mass removal rate.
# * [Assignment 2 (45 pts)](#a2) Poisson/Dirichlet 2-D model problem revisited.
#  - [2.1)](#a21)(35 pts) Compute convection velocity.
#  - [2.2)](#a22)(10 pts) Outflow condition.
# * [Assignment 3 (5 pts)](#a3)
# ---

# %% [markdown]
# ### <span style="color:blue">Given the Peclet concentration axisymmetric model problem:</span>
# <br>
# <span style="color:blue">
#
# Compute the temperature function $u:\Omega\subset\Reals^2\rightarrow\Reals$ such that:
#
# \begin{align*}
#   \grad_x u \cdot \velocity &= -\div_x\bigl(-D\, \grad_x u\bigr) + S \quad \forall \quad x\in \Omega, \\
#  u(\xpoint) &= u_\text{in} \quad \text{on} \quad \partial\Omega_\text{in}, \\
#  q_{n,\text{cl}}(\xpoint) &= 0 \quad \text{on} \quad \text{center line} \\
#  q_{n,\text{o}}(\xpoint) & = 0 \quad \text{on} \quad \text{outflow} \\
#  q_{n,\text{w}}(\xpoint) & = h\,\bigl(u(\xpoint) - u^*\bigr) \quad \text{on} \quad \text{wall}
# \end{align*}
#
# where the parameters:
#  + flow velocity, $\velocity$,
#  + diffusion coefficient, $D$,
#  + mass source, $S$,
#  + inlet concentration, $c_\text{b}$,
#  + wall diffusion, $q_{n,\text{w}}$,
#  + mass transfer coefficient, $h$,
#  + saturation concentration in the solid pipe, $u^*$, and
#  + rectangular domain $\Omega$, with boundary $\partial\Omega$,
#
# are given below, where the mass diffusion flux, $\flux:\Omega\rightarrow\Reals^2$, associated to the concentration $u$, is defined as $\flux := -D\,\grad u$.
#
# </span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 1 (40 pts)](#toa)</span><a id="a1"></a>

# %% [markdown]
# ### <span style="color:blue">[1.1)](#toa)(10 pts) State the Galerkin weak formulation of the problem.
# </span><a id="a11"></a>

# %% [markdown]
# ### <span style="color:blue">[1.2)](#toa)(10 pts) When is the weak formulation equivalent to a variational formulation? Demonstrate the minimization problem.
# </span><a id="a12"></a>

# %% [markdown]
# ### <span style="color:blue">[1.3)](#toa)(10 pts) Using the Galerkin FEM and the MOOSE framework solve the mass transport problem stated above on the $r-z$ plane of the cylindrical domain using the following parameters:</span>
# <br>
# <span style="color:blue">
#
# |       Description          |      Value         |            Units               |
# |----------------------------|--------------------|--------------------------------|
# | Pipe diameter |   $3/4$               | $\text{inch}$                    |
# | Pipe length to diameter ratio    |     $4.5$               | -   |
# | Diffusion coefficient      |   $5\times 10^{-5}$   | $\frac{\text{m}^2}{\text{s}}$ |
# | Source                         |   $1.13$              | $\frac{\mu\text{g}}{\text{cc min}}$ |
# | Mass transfer coefficient |  $13$ | $\frac{\text{mm}}{\text{min}}$ |
# | Saturation concentration in solid |  $0.1$ | $\frac{\text{$\mu$g}}{\text{cc}}$  |
# | Flow velocity ($v_r$, $v_\theta$, $v_z$)| (0, 0, 0) | $\frac{cm}{s}$ |
# | Inflow concentration      | $3.1$    | $\frac{\text{$\mu$g}}{\text{cc}}$   |
#
# </span>
#
# ### <span style="color:blue">Reproduce the results below using quadratic Lagrange FEM basis functions and report on the FEM parameters needed.</span><a id="a13"></a>

# %%
'''Domain'''

# %%
'''Domain viz for info purposes'''
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F8623FADD30>

# %%
'''Parameters and data'''

# %%
'''FEM Solution and Flux'''

# %%
'''Display MOOSE input file created'''

# !cat engy5310p1/input.hit
# Out:
# # Engy-5310 Problem: Poisson 2D FEM
# # UMass Lowell Nuclear Chemical Engineering
# # Prof. Valmor F. de Almeida
# # 18Apr21 18:43:01
#
# # Parameters
# xmin = 0.00000e+00
# xmax = 9.52500e-03
# ymin = 0.00000e+00
# ymax = 8.57250e-02
# diff_coeff = 5.00000e-05
# source_s = 1.88333e-05
# u_bottom = 3.10000e-03
# qn_bias_left = 0.00000e+00
# transfer_coeff_right = 2.16667e-04
# u_reference_right = 1.00000e-04
# qn_bias_top = 0.00000e+00
#
# [Problem]
#   type = FEProblem
#   coord_type = RZ
#   rz_coord_axis = Y
# []
#
# [Mesh]
#   [2d]
#     type = GeneratedMeshGenerator
#     dim = 2
#     xmin = ${replace xmin}
#     xmax = ${replace xmax}
#     ymin = ${replace ymin}
#     ymax = ${replace ymax}
#     nx = 15
#     ny = 135
#     elem_type = QUAD9
#   []
# []
#
# [Variables]
#   [u]
#     order = second
#     family = lagrange
#   []
# []
#
# [AuxVariables]
#   [diffFluxU]
#     order = FIRST
#     family = MONOMIAL_VEC
#   []
#   [diffFluxU_x]
#     order = FIRST
# ...

# %%
'''Run Engy5310P1 MOOSE App'''
# Out:
# Framework Information:
# MOOSE Version:           git commit 52562be492 on 2021-04-09
# LibMesh Version:         27141d18f3137f77e33cdb3d565fd38ebfbfc46f
# PETSc Version:           3.15.0
# SLEPc Version:           3.14.2
# Current Time:            Sun Apr 18 18:43:02 2021
# Executable Timestamp:    Sat Apr 17 21:27:24 2021
#
# Parallelism:
#   Num Processors:          1
#   Num Threads:             1
#
# Mesh:
#   Parallel Type:           replicated
#   Mesh Dimension:          2
#   Spatial Dimension:       2
#   Nodes:
#     Total:                 8401
#     Local:                 8401
#   Elems:
#     Total:                 2025
#     Local:                 2025
#   Num Subdomains:          1
#   Num Partitions:          1
#
# Nonlinear System:
#   Num DOFs:                8401
#   Num Local DOFs:          8401
#   Variables:               "u"
#   Finite Element Types:    "LAGRANGE"
#   Approximation Orders:    "SECOND"
#
# Auxiliary System:
#   Num DOFs:                24300
# ...

# %%
'''Show 2D solution'''
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F864C1D8D30>

# %%
'''Show 2D solution'''
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F85C1C22A90>

# %%
'''Show 2D solution'''
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F86545E8EE0>

# %%
'''Show FEM Solution and Flux'''
# Out:
# Conc. max. =     1.29 [ug/cc]
# Conc. min. =     1.27 [ug/cc]
# Radial Diff. flux abs. max. = 91.22 [ug/cm^2/h]
# Radial Diff. flux abs. min. = 0.00 [ug/cm^2/h]

# %%
'''Show FEM Solution and Flux'''
# Out:
# Conc. max. =     3.10 [ug/cc]
# Conc. min. =     0.90 [ug/cc]
# Radial Diff. flux abs. max. = 261.13 [ug/cm^2/h]
# Radial Diff. flux abs. min. = 62.54 [ug/cm^2/h]

# %% [markdown]
# #### <span style="color:blue">Explain the oscillations on the plot above.</span>
# </span>

# %% [markdown]
# ### <span style="color:blue">[1.4)](#toa)(10 pts) Compute the mass rate removed from the system through the pipe wall.</span>
# </span><a id="a14"></a>

# %%
# Out:
# Mass removed =  5.575e+00 [mg/h]

# %% [markdown]
# ## <span style="color:blue">[Assignment 2 (45 pts)](#toa)</span><a id="a2"></a>

# %% [markdown]
# ### <span style="color:blue">[2.1)](#toa)(35 pts) Using the Galerkin FEM and the MOOSE framework solve the diffusion problem in 1.3) with the same FEM parameters, however,  compute the axial velocity component that, at the minimum, doubles the mass removal rate of the system.</span>
#
# |       Description          |      Value         |            Units               |
# |----------------------------|--------------------|--------------------------------|
# | Flow velocity ($v_r$, $v_\theta$, $v_z$)| (0, 0, ?) | $\frac{cm}{s}$ |
#
# </span><a id="a21"></a>

# %%
'''Code'''

# %%
'''Show 2D solution'''
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8568287400>

# %%
'''Show 2D solution'''
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F85681FD820>

# %%
'''Show 2D solution'''
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8568203CA0>

# %%
'''Show FEM Solution and Flux'''
# Out:
# Conc. max. =     2.98 [ug/cc]
# Conc. min. =     2.93 [ug/cc]
# Radial Diff. flux abs. max. = 220.41 [ug/cm^2/h]
# Radial Diff. flux abs. min. = 0.00 [ug/cm^2/h]

# %%
'''Show FEM Solution and Flux'''
# Out:
# Conc. max. =     3.10 [ug/cc]
# Conc. min. =     2.79 [ug/cc]
# Radial Diff. flux abs. max. = 257.36 [ug/cm^2/h]
# Radial Diff. flux abs. min. = 99.33 [ug/cm^2/h]

# %%
# Out:
# Mass removed =  1.130e+01 [mg/h]

# %% [markdown]
# ### <span style="color:blue">[2.2)](#toa)(10 pts) Plot the axial diffusion flux at the center line and comment on the result implications to this model.</span>
#
# </span><a id="a22"></a>

# %%
'''Show FEM Solution and Flux'''
# Out:
# Conc. max. =     3.10 [ug/cc]
# Conc. min. =     2.84 [ug/cc]
# Axial Diff. flux abs. max. = 60.56 [ug/cm^2/h]
# Axial Diff. flux abs. min. = 0.69 [ug/cm^2/h]

# %% [markdown]
# #### <span style="color:blue">Comments.</span>
# </span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 3 (5 pts)](#toa)</span><a id="a3"></a>

# %% [markdown]
# ### <span style="color:blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</span>

# %% [markdown]
# **Answer:**
