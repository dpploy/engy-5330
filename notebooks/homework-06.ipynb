# %% [markdown]
# Engy-5310: Computational Continuum Transport Phenomena Spring 2021 UMass Lowell; Prof. V. F. de Almeida **19Feb21**
#
# # Howmework 06 (19Feb21)
#
# $
#   \newcommand{\Amtrx}{\boldsymbol{\mathsf{A}}}
#   \newcommand{\Bmtrx}{\boldsymbol{\mathsf{B}}}
#   \newcommand{\Mmtrx}{\boldsymbol{\mathsf{M}}}
#   \newcommand{\Imtrx}{\boldsymbol{\mathsf{I}}}
#   \newcommand{\Pmtrx}{\boldsymbol{\mathsf{P}}}
#   \newcommand{\Lmtrx}{\boldsymbol{\mathsf{L}}}
#   \newcommand{\Umtrx}{\boldsymbol{\mathsf{U}}}
#   \newcommand{\Smtrx}{\boldsymbol{\mathsf{S}}}
#   \newcommand{\xvec}{\boldsymbol{\mathsf{x}}}
#   \newcommand{\avec}{\boldsymbol{\mathsf{a}}}
#   \newcommand{\bvec}{\boldsymbol{\mathsf{b}}}
#   \newcommand{\cvec}{\boldsymbol{\mathsf{c}}}
#   \newcommand{\rvec}{\boldsymbol{\mathsf{r}}}
#   \newcommand{\fvec}{\boldsymbol{\mathsf{f}}}
#   \newcommand{\mvec}{\boldsymbol{\mathsf{m}}}
#   \newcommand{\gvec}{\boldsymbol{\mathsf{g}}}
#   \newcommand{\zerovec}{\boldsymbol{\mathsf{0}}}
#   \newcommand{\norm}[1]{\bigl\lVert{#1}\bigr\rVert}
#   \newcommand{\transpose}[1]{{#1}^\top}
#   \DeclareMathOperator{\rank}{rank}
#   \newcommand{\Reals}{\mathbb{R}}
#   \newcommand{\thetavec}{\boldsymbol{\theta}}
# $

# %% [markdown]
# ### Name: `your name`

# %% [markdown]
# ### Rubric for each assignment:
#
# |       Context               |  Points |
# | -----------------------     | ------- |
# | Precision of the answer     |   80%   |
# | Answer Markdown readability |   10%   |
# | Code readability            |   10%   |

# %% [markdown]
# ### <span style="color:red">Guidance:</span>
#
# +  <span style="color:red">
#     Save your work frequently to a file locally to your computer.
#    </span>
# +  <span style="color:red">
#     During your work and before submitting the final version do:</span> Kernel -> Restart & Run All<span style="color:red">, to verify your notebook runs correctly.
#    </span>
# +  <span style="color:red">
#     Save your file again.
#    </span>
# +  <span style="color:red">
#     Upload the notebook file in the Blackboard submission portal as:
#    </span>
#
#    **lastname-firstname-labwork-xx.ipynb**

# %% [markdown]
# ---
# ## Table of Assignments<a id="toa"></a>
# * [Assignment 1 (95 pts)](#a1) Function approximation with basis functions.
#  - [1.1)](#a11)(20 pts) Generate a function solving a 1D Poisson problem.
#  - [1.2)](#a12)(25 pts) Approximate function with 2 Fourier modes.
#  - [1.3)](#a13)(25 pts) Approximate function with 3 Fourier modes.
#  - [1.4)](#a14)(25 pts) Approximate function with quadratic Legendre basis functions.
# * [Assignment 2 (5 pts)](#a2)
# ---

# %% [markdown]
# ## <span style="color:blue">[Assignment 1 (95 pts)](#toa)</span><a id="a1"></a>

# %% [markdown]
# ### <span style="color:blue">[1.1)](#toa)(20 pts) Solve the Poisson model problem below.</span>
# <br>
# <span style="color:blue">
#
# Find $f:[a,b]\in\Reals\rightarrow\Reals$ for $C \ne 0$ such that:
#
# \begin{align*}
#  f''(x) &= C \quad \forall \quad x\in [a,b], \\
#  f(a) &= A, \\
#  f(b) &= B.
# \end{align*}
#
# for the values
#   + $\hat{x}^* = 0$,
#   + $\hat{f}^* := f(\hat{x}^*) = 1$ .
#
# Define $L:= b-a$, $\hat{x} := \frac{x-a}{L} - \frac{1}{2}$, and $\hat{f}(\hat{x}) := \frac{f(x)}{C\,L^2} + \frac{1}{8}$. Denote the point $\bigl(\hat{x}^*, \hat{f}^*\bigr)$ as the <b>minimum</b> of the solution $\hat{f}:[-\frac{1}{2},\frac{1}{2}]\in\Reals\rightarrow\Reals$ of the problem.
#
# Make a plot of the solution.
# <span style="color:blue"> </span><a id="a11"></a>

# %%
'''1-D Poisson equation solution f'''

# %% [markdown]
# ### <span style="color:blue">[1.2)](#toa)(25 pts) Compute an approximant function $g$ using a Fourier basis function of 2 modes approximation by minimizing the residual vector on 7 equally spaced collocation points in $x$, Explain the goodness of the approximation.
# </span><a id="a12"></a>

# %%
'''Collocation abscissa points'''

# %%
'''Build the basis function evaluation matrix and target function vector at the collocation points'''
# Out:
# A is overdetermined.

# %%
'''Compute optimal coefficient vector'''
# Out:
# A is full rank.
#
# ||r^*||_2 =  1.777e-02

# %%
'''Build the best approximant function'''

# %%
'''Plot comparison of f and g_best_vec'''

# %%
'''L2 norm error'''
# Out:
# ||f||_L2 = (1.0423331201364243, 1.2062110569625401e-14)
#
# ||g||_L2 = 1.0454786895990473
# quadrature error = 1.2135022918673773e-14
#
# ||f-g||_L2 = 0.04778846093388311
# quadrature error = 3.1513459308979246e-14
#
# Relative error [%] = 4.584758942287892

# %%
'''Residual of the best approximant'''
# Out:
# Positives at collocation pts =  4
# Negatives at collocation pts =  3
# Positives =  102
# Negatives =  148

# %% [markdown]
# <span style="color:blue">
# <b>Explanation:</b>
# </span>

# %% [markdown]
# ### <span style="color:blue">[1.3)](#toa)(25 pts) Compute an approximant function $g$ using a Fourier basis function of 3 modes approximation by minimizing the residual vector on 7 equally spaced collocation points in $x$. Compare with Assignment 1.2), plot the residual and explain the result.
# </span><a id="a13"></a>

# %%
'''Build the basis function evaluation matrix and target function vector at the collocation points'''
# Out:
# A is determined.

# %%
'''Compute optimal coefficient vector'''
# Out:
# A is rank deficient.
#
# ||r^*||_2 =  6.662e-08

# %%
'''Build the best approximant function'''

# %%
'''Plot comparison of f and g_best_vec'''

# %%
'''L2 norm error'''
# Out:
# ||f||_L2 = (1.0423331201364243, 1.2062110569625401e-14)
#
# ||g||_L2 = 1.044813893228333
# quadrature error = 1.9925332868028778e-11
#
# ||f-g||_L2 = 0.04669223313154438
# quadrature error = 1.089898773174499e-10
#
# Relative error [%] = 4.479588360910294

# %%
'''Residual of the best approximant'''
# Out:
# Positives at collocation pts =  7
# Negatives at collocation pts =  0
# Positives =  86
# Negatives =  164

# %% [markdown]
# <span style="color:blue">
# <b>Explanation:</b>
# </span>

# %% [markdown]
# ### <span style="color:blue">[1.4)](#toa)(25 pts) Compute an approximant function $g$ using quadratic Legendre  functions by minimizing the residual vector on 3 equally spaced collocation points in $x$. Plot the residual and explain the result.
# </span><a id="a14"></a>

# %%
'''Collocation abscissa points'''

# %%
'''Build the basis function evaluation matrix and target function vector at the collocation points'''
# Out:
# A is determined.

# %%
'''Compute optimal coefficient vector'''
# Out:
# A is full rank.
#
# ||r^*||_2 =  0.000e+00

# %%
'''Build the best approximant function'''

# %%
'''Plot comparison of f and g_best_vec'''

# %%
'''Relative L2 norm error'''
# Out:
# ||f||_L2 = (1.0423331201364243, 1.2062110569625401e-14)
#
# ||g||_L2 = 1.0423331201364243
# quadrature error = 1.2062110569625401e-14
#
# ||f-g||_L2 = 0.0
# quadrature error = 0.0
#
# Relative error [%] = 0.0

# %%
'''Residual of the best approximant'''
# Out:
# Positives at collocation pts =  0
# Negatives at collocation pts =  0
# Positives =  0
# Negatives =  0

# %% [markdown]
# <span style="color:blue">
# <b>Explanation:</b>
# </span>

# %% [markdown]
# ## <span style="color:blue">[Assignment 2 (5 pts)](#toa)</span><a id="a2"></a>

# %% [markdown]
# ### <span style="color:blue">Describe the most unclear point in the content presented so far. Then, make an effort to clarify the point on your own.</span>

# %% [markdown]
# **Answer:**
